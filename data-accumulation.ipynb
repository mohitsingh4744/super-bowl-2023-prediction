# %%
from tbMethod import *
import pandas as pd

# %% [markdown]
# # Obtaining training data
# The following code runs through the 2002-2021 NFL seasons and obtains offensive and defensive team data from each regular season. Then, it downloads the dataframe as a local csv.

# %%
dataframes = []
for i in range(2002, 2022):
    df_temp = tableMethod(year=i, input_id='team_stats', url2='https://www.pro-football-reference.com/years/{}/')
    df_temp['Year'] = i
    df_temp2 = df_temp[0:32]
    dataframes.append(df_temp2)
df_off = pd.concat(dataframes)
df_off
# Out:
#                       Tm   G   PF   Yds   Ply  Y/P  TO  FL 1stD  Cmp  ...  TD  \
# 0     Kansas City Chiefs  16  467  6000   965  6.2  15   2  343  292  ...  26
# 1        Oakland Raiders  16  450  6237  1069  5.8  19   9  366  418  ...  21
# 2     New Orleans Saints  16  432  5205  1001  5.2  30  15  291  291  ...  16
# 3    Philadelphia Eagles  16  415  5604  1073  5.2  24  13  311  318  ...  15
# 4        Atlanta Falcons  16  402  5535  1038  5.3  27  15  316  268  ...  23
# ..                   ...  ..  ...   ...   ...  ...  ..  ..  ...  ...  ...  ..
# 27         New York Jets  17  310  5208  1036  5.0  27   7  310  357  ...  14
# 28     Carolina Panthers  17  304  5081  1106  4.6  29   8  322  348  ...  17
# 29        Houston Texans  17  280  4727  1010  4.7  22   7  266  354  ...   8
# 30       New York Giants  17  258  4884  1050  4.7  30  10  299  351  ...   8
# 31  Jacksonville Jaguars  17  253  5191  1028  5.0  29  12  304  361  ...  13
#
# ...

# %%
def_dataframes = []
for i in range(2002, 2022):
    df_temp = tableMethod(year=i, input_id='team_stats', url2='https://www.pro-football-reference.com/years/{}/opp.htm')
    df_temp['Year'] = i
    df_temp2 = df_temp[0:32]
    def_dataframes.append(df_temp2)
df_def = pd.concat(def_dataframes)
df_def
# Out:
#                       Tm   G   PA   Yds   Ply  Y/P  TO  FL 1stD  Cmp  ...  TD  \
# 0   Tampa Bay Buccaneers  16  196  4044   963  4.2  38   7  236  259  ...   8
# 1    Philadelphia Eagles  16  241  4754  1009  4.7  38  23  272  333  ...   5
# 2        New York Giants  16  279  4949   985  5.0  25  14  266  311  ...  12
# 3         Miami Dolphins  16  301  4656   974  4.8  30   9  285  294  ...   9
# 4      Carolina Panthers  16  302  4646  1022  4.5  33  16  271  293  ...  12
# ..                   ...  ..  ...   ...   ...  ...  ..  ..  ...  ...  ...  ..
# 27  Jacksonville Jaguars  17  457  6002  1068  5.6   9   2  351  377  ...  22
# 28       Atlanta Falcons  17  459  6194  1114  5.6  20   8  383  391  ...  19
# 29  Los Angeles Chargers  17  459  6122  1103  5.6  21  10  383  357  ...  22
# 30         Detroit Lions  17  467  6456  1092  5.9  19   8  372  359  ...  19
# 31         New York Jets  17  504  6760  1145  5.9  14   7  401  401  ...  28
#
# ...

# %%
df_off.to_csv("NFL-offense-test-data.csv")

# %%
df_def.to_csv("NFL-defense-test-data.csv")

# %% [markdown]
# # Obtaining test data
# The code below obtains the offensive and defensive data of the current regular season.

# %%
df_2022_off = tableMethod(year=2022, input_id='team_stats', url2='https://www.pro-football-reference.com/years/{}/')
df_2022_def = tableMethod(year=2022, input_id='team_stats', url2='https://www.pro-football-reference.com/years/{}/opp.htm')

# %%
df_2022_off
# Out:
#                        Tm   G     PF     Yds     Ply  Y/P    TO   FL   1stD  \
# 0      Kansas City Chiefs  17    496    7032    1094  6.4    23   11    408
# 1     Philadelphia Eagles  17    477    6614    1124  5.9    19   10    385
# 2          Dallas Cowboys  17    467    6034    1114  5.4    23    5    347
# 3           Buffalo Bills  16    455    6361    1037  6.1    27   13    367
# 4           Detroit Lions  17    453    6460    1092  5.9    15    8    376
# 5     San Francisco 49ers  17    450    6216    1047  5.9    17    8    347
# 6       Minnesota Vikings  17    424    6145    1123  5.5    23    8    382
# 7      Cincinnati Bengals  16    418    5768    1053  5.5    18    6    357
# 8        Seattle Seahawks  17    407    5976    1044  5.7    23   11    346
# 9    Jacksonville Jaguars  17    404    6075    1072  5.7    22   13    352
# 10         Miami Dolphins  17    397    6197    1009  6.1    21    6    342
# ...

# %%
df_2022_off.to_csv("NFL-offense-testing-data.csv")

# %%
df_2022_def.to_csv("NFL-defense-testing-data.csv")

# %% [markdown]
# # Break here for now!

# %%
df_off = df_off.sort_values(by=['Tm', 'Year']).reset_index()
df_off = df_off.add_prefix('off_')
df_def = df_def.sort_values(by=['Tm', 'Year']).reset_index()
df_def = df_def.add_prefix('def_')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df_off = df_off.sort_values(by=['Tm', 'Year'])
#       2 df_off = df_off.add_prefix('off_')
#       3 df_def = df_def.sort_values(by=['Tm', 'Year'])
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pandas/core/frame.py:6891, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
# ...

# %%
df_test = pd.merge(df_off, df_def, left_on=['off_Tm', 'off_Year'], right_on=['def_Tm', 'def_Tm'])
df_test
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df_test = pd.merge(df_off, df_def, left_on=['off_Tm', 'off_Year'], right_on=['def_Tm', 'def_Tm'])
#       2 df_test
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pandas/core/reshape/merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
# ...

# %%
df_off
# Out:
#                       Tm   G   PF   Yds   Ply  Y/P  TO  FL 1stD  Cmp  ...  TD  \
# 0     Kansas City Chiefs  16  467  6000   965  6.2  15   2  343  292  ...  26
# 1        Oakland Raiders  16  450  6237  1069  5.8  19   9  366  418  ...  21
# 2     New Orleans Saints  16  432  5205  1001  5.2  30  15  291  291  ...  16
# 3    Philadelphia Eagles  16  415  5604  1073  5.2  24  13  311  318  ...  15
# 4        Atlanta Falcons  16  402  5535  1038  5.3  27  15  316  268  ...  23
# ..                   ...  ..  ...   ...   ...  ...  ..  ..  ...  ...  ...  ..
# 27         New York Jets  17  310  5208  1036  5.0  27   7  310  357  ...  14
# 28     Carolina Panthers  17  304  5081  1106  4.6  29   8  322  348  ...  17
# 29        Houston Texans  17  280  4727  1010  4.7  22   7  266  354  ...   8
# 30       New York Giants  17  258  4884  1050  4.7  30  10  299  351  ...   8
# 31  Jacksonville Jaguars  17  253  5191  1028  5.0  29  12  304  361  ...  13
#
# ...

# %%
df_def
# Out:
#                  def_Tm def_G def_PA def_Yds def_Ply def_Y/P def_TO def_FL  \
# 28    Arizona Cardinals    16    417    6020    1046     5.8     25      8
# 31    Arizona Cardinals    16    452    5504     993     5.5     23     10
# 11    Arizona Cardinals    16    322    5141     993     5.2     30     15
# 25    Arizona Cardinals    16    387    4729     936     5.1     26     11
# 28    Arizona Cardinals    16    389    5591    1018     5.5     33     17
# ..                  ...   ...    ...     ...     ...     ...    ...    ...
# 16  Washington Redskins    16    379    6090    1010     6.0     27     16
# 18  Washington Redskins    16    383    6046    1050     5.8     21      8
# 27  Washington Redskins    16    388    5566    1045     5.3     23      7
# 14  Washington Redskins    16    359    5654     996     5.7     26     11
# 26  Washington Redskins    16    435    6162    1079     5.7     22      9
#
# ...

# %%
df_super_bowl_winners = pd.read_csv('super-bowl-winners.csv')
df_super_bowl_winners
# Out:
#            Date            SB                Winner  Pts  \
# 0   Feb 13 2022      LVI (56)      Los Angeles Rams   23
# 1    Feb 7 2021       LV (55)  Tampa Bay Buccaneers   31
# 2    Feb 2 2020      LIV (54)    Kansas City Chiefs   31
# 3    Feb 3 2019     LIII (53)  New England Patriots   13
# 4    Feb 4 2018      LII (52)   Philadelphia Eagles   41
# 5    Feb 5 2017       LI (51)  New England Patriots   34
# 6    Feb 7 2016            50        Denver Broncos   24
# 7    Feb 1 2015     XLIX (49)  New England Patriots   28
# 8    Feb 2 2014   XLVIII (48)      Seattle Seahawks   43
# 9    Feb 3 2013    XLVII (47)      Baltimore Ravens   34
# 10   Feb 5 2012     XLVI (46)       New York Giants   21
# 11   Feb 6 2011      XLV (45)     Green Bay Packers   31
# 12   Feb 7 2010     XLIV (44)    New Orleans Saints   31
# 13   Feb 1 2009    XLIII (43)   Pittsburgh Steelers   27
# 14   Feb 3 2008     XLII (42)       New York Giants   17
# ...
